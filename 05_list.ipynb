# %%
l = []
type(l)
# Out:
# list

# %%
l1 = list()
type(l1)
# Out:
# list

# %%
l2 = [1,2,3,"Anand",'c',bool,2*3]
l2
# Out:
# [1, 2, 3, 'Anand', 'c', bool, 6]

# %%
type(l2)
# Out:
# list

# %%
l2[2]
# Out:
# 3

# %%
l3 = [1,2,4,[5,36,45,'Anans'],3,34.2+8j]
l3
# Out:
# [1, 2, 4, [5, 36, 45, 'Anans'], 3, (34.2+8j)]

# %%
l3[3][3]
# Out:
# 'Anans'

# %%
l3[3][0:4]
# Out:
# [5, 36, 45, 'Anans']

# %%
l3[5]
# Out:
# (34.2+8j)

# %%
a = l3[5]

# %%
a.real
# Out:
# 34.2

# %%
a.imag
# Out:
# 8.0

# %%
l3[::-1]
# Out:
# [(34.2+8j), 3, [5, 36, 45, 'Anans'], 4, 2, 1]

# %%
l3[3][3][3]
# Out:
# 'n'

# %%
list()
# Out:
# []

# %%
l3[1] ="Gupta"

# %%
print(l3)
# Out:
# [1, 'Gupta', 4, [5, 36, 45, 'Anans'], 3, (34.2+8j)]

# %%
a = "Nitin"
a[2] = 'g'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[62], line 2
#       1 a = "Nitin"
# ----> 2 a[2] = 'g'
#
# TypeError: 'str' object does not support item assignment

# %%
l3[1][2] = 's'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 l3[1][2] = 's'
#
# TypeError: 'str' object does not support item assignment

# %%
l3[4] = [1,234,45,'t']

# %%
l3
# Out:
# [1, 'Gupta', 4, [5, 36, 45, 'Anans'], [1, 234, 45, 't'], (34.2+8j)]

# %%
list("anand")
# Out:
# ['a', 'n', 'a', 'n', 'd']

# %%
list(['anand'])
# Out:
# ['anand']

# %%
l4 = [23,45,"Anand",[2,3,4,5],23+34j]

# %%
l4
# Out:
# [23, 45, 'Anand', [2, 3, 4, 5], (23+34j)]

# %%
len(l4)
# Out:
# 5

# %%
l4.append(6)
l4
# Out:
# [23, 45, 'Anand', [2, 3, 4, 5], (23+34j), 6, 6]

# %%
l4.extend("anand")
l4
# Out:
# [23,
#  45,
#  'Anand',
#  [2, 3, 4, 5],
#  (23+34j),
#  6,
#  6,
#  'g',
#  'u',
#  'p',
#  't',
#  'a',
#  'g',
#  'u',
#  'p',
#  't',
#  'a',
#  'a',
#  'n',
#  'a',
#  'n',
#  'd',
#  'a',
#  'n',
#  'a',
#  'n',
#  'd']

# %%
l5 = [4,5,6,"Anand"]

# %%
l5.insert(1,"Nitin")
l5
# Out:
# [4, 'Nitin', 'gup', 'gup', 5, 6, 'Anand']

# %%
l5.insert(5,[6,7,1])
l5
# Out:
# [4, 'Nitin', 'gup', [4, 6, 7], [4, 6, 7], [6, 7, 1], 'gup', 5, 6, 'Anand']

# %%
l5.remove([4,6,7])
l5
# Out:
# [4, 'Nitin', 'gup', [4, 6, 7], [6, 7, 1], 'gup', 6, 'Anand']

# %%
l5.pop()
# Out:
# 'Anand'

# %%
l5.pop(3)
# Out:
# [4, 6, 7]

# %%
l5
# Out:
# [4, 'Nitin', 'gup', [6, 7, 1], 'gup', 6]

# %%
l5.index(6)
# Out:
# 5

# %%
l5.count(6)
# Out:
# 1

# %%
l6 = [3,4,65,3,4,2,5,3,23,43,54,45]

# %%
l6.sort()
l6
# Out:
# [2, 3, 3, 3, 4, 4, 5, 23, 43, 45, 54, 65]

# %%
l6.sort(reverse=True)
l6
# Out:
# [65, 54, 45, 43, 23, 5, 4, 4, 3, 3, 3, 2]

# %%
l7 = ["Nitin","Virat","Anand"]
l7.sort()
l7
# Out:
# ['Anand', 'Nitin', 'Virat']

# %%
l5[::-1]
# Out:
# [6, 'gup', [6, 7, 1], 'gup', 'Nitin', 4]

# %%
l5.reverse()
l5
# Out:
# [4, 'Nitin', 'gup', [6, 7, 1], 'gup', 6]

# %%
l7.copy()
# Out:
# ['Anand', 'Nitin', 'Virat']

# %%
l8 = [2,3,5]
l8
# Out:
# [2, 3, 5]

# %%
l10 = l8.copy()

# %%
l9 = l8

# %%
l9
# Out:
# [2, 3, 5]

# %%
l8[2] = "Anand"

# %%
l9 # Here the vlaue in L9 will be chnage as it is fdeep copy and it is creatd in same box
# Out:
# [2, 3, 'Anand']

# %%
l10 # there will be no any chnage will occure if chnage the value in shallow copy
# Out:
# [2, 3, 5]

# %%
l10[0] = 2323424

# %%
l10
# Out:
# [2323424, 3, 5]

# %%
l8
# Out:
# [2, 3, 'Anand']

# %%
l9[2] = 454

# %%
l8
# Out:
# [2, 3, 454]

# %%
min(l8)
# Out:
# 2

# %%
sorted(l8)
# Out:
# [2, 3, 454]

# %%
list(reversed(l8))
# Out:
# [454, 3, 2]
